# %% [markdown]
# # Hola Cientificos

# %%
import numpy as np

# %%
lista = [[1, 2, 3, 4],[3, 4, 5, 6], [5, 6, 7, 8]]

array_1d = np.array(lista, dtype='float')


#Checamos el tipo de dato de array_id
type(array_1d)

#contenido del array
array_1d
# Out:
# array([[1., 2., 3., 4.],
#        [3., 4., 5., 6.],
#        [5., 6., 7., 8.]])

# %%
# ndim
print('Dimensiones: ', array_1d.ndim)
# shape
print("Shape: ", array_1d.shape)
# size
print("Size: ", array_1d.size)
# Out:
# Dimensiones:  2
# Shape:  (3, 4)
# Size:  12

# %% [markdown]
# # Hola Cientificos

# %%
import random

# %%
def generar_matriz(N):
    matriz= []
    for i in range (N):
        fila = []
        for j in range(N):
            fila.append(random.randint(1, 9))
        matriz.append(fila)
    return matriz

N = 5

matriz_aleatoria = generar_matriz(N)
for fila in matriz_aleatoria:
    print(fila)

def imprimir_matriz(matriz):
    for fila in matriz:
        fila_formateada = ' '.join(f'{elemento:2}' for elemento in fila)
        print(fila_formateada)
# Out:
# [7, 5, 8, 8, 7]
# [4, 1, 3, 1, 6]
# [7, 5, 3, 7, 1]
# [5, 9, 4, 6, 9]
# [4, 8, 2, 5, 6]

# %%
print("Matriz de 5x5")
m_5 = generar_matriz(5)
imprimir_matriz(m_5)
print("============")
print("Matriz de 10x10")
m_10 = generar_matriz(10)
imprimir_matriz(m_10)
print("============")
print("Matriz de 20x20")
m_20 = generar_matriz(20)
imprimir_matriz(m_20)
# Out:
# Matriz de 5x5
#  7  7  1  1  2
#  5  5  9  7  2
#  6  3  4  2  1
#  4  7  1  3  7
#  4  2  5  1  6
# ============
# Matriz de 10x10
#  5  4  2  7  7  2  2  8  2  6
#  4  6  6  4  9  4  4  4  5  2
#  2  9  9  7  3  1  3  9  2  2
#  1  3  1  6  1  8  9  7  9  1
#  9  6  3  6  4  4  1  7  7  1
#  4  7  6  9  1  8  9  6  2  5
#  5  8  3  9  7  2  5  9  9  8
#  7  9  3  8  6  7  9  4  1  1
#  7  7  1  1  6  1  1  3  4  6
#  6  6  9  6  1  9  2  2  7  6
# ============
# Matriz de 20x20
#  2  9  7  6  7  7  2  7  8  4  8  8  2  8  4  3  6  7  5  4
#  8  9  2  2  5  9  6  9  6  8  6  8  1  7  3  1  6  5  9  1
#  7  6  1  5  8  7  8  7  8  9  5  8  1  9  5  6  4  5  4  2
#  7  3  4  1  3  5  2  3  1  6  7  5  8  7  9  8  3  8  4  4
#  3  1  4  7  1  3  8  9  8  3  8  3  6  1  1  5  8  3  4  9
#  8  9  4  1  9  8  6  9  3  3  2  5  6  2  9  1  3  5  4  6
#  4  6  8  8  7  4  2  4  5  6  4  6  7  7  7  6  2  1  8  8
#  8  8  5  8  3  2  6  2  9  2  3  5  8  3  2  8  8  7  2  2
#  6  1  6  9  1  5  3  5  8  4  5  6  2  8  2  5  3  8  3  7
#  2  2  4  5  2  6  7  8  7  9  5  7  5  7  4  1  8  3  5  6
#  3  4  5  9  4  1  2  8  6  3  5  8  3  2  4  4  2  9  2  7
#  9  8  3  9  9  1  5  3  8  5  7  4  9  1  6  2  7  7  4  7
#  4  7  1  3  2  8  4  5  7  8  1  9  8  1  5  3  9  4  5  8
#  9  6  1  4  4  2  8  8  7  3  3  7  8  7  6  9  3  1  9  3
#  4  2  5  6  4  7  5  9  2  6  3  5  9  6  7  6  8  7  3  7
#  6  2  2  8  3  7  5  7  4  1  5  8  9  9  2  1  4  4  1  1
#  5  3  1  1  9  3  6  1  4  6  4  1  6  2  8  4  2  3  3  7
#  8  4  4  7  5  4  2  3  6  3  6  6  8  2  7  8  2  8  4  5
#  5  7  2  1  7  6  5  8  2  6  1  7  1  2  9  9  7  2  7  7
#  9  4  5  5  3  7  1  8  8  9  1  5  5  1  2  5  5  6  3  8
