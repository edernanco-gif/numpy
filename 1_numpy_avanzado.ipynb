# %% [markdown]
# # Hola Cientificos

# %%
import numpy as np

# %%
lista = [[1, 2, 3, 4],[3, 4, 5, 6], [5, 6, 7, 8]]

array_1d = np.array(lista, dtype='float')


#Checamos el tipo de dato de array_id
type(array_1d)

#contenido del array
array_1d
# Out:
# array([[1., 2., 3., 4.],
#        [3., 4., 5., 6.],
#        [5., 6., 7., 8.]])

# %%
# ndim
print('Dimensiones: ', array_1d.ndim)
# shape
print("Shape: ", array_1d.shape)
# size
print("Size: ", array_1d.size)
# Out:
# Dimensiones:  2
# Shape:  (3, 4)
# Size:  12

# %% [markdown]
# # Hola Cientificos

# %%
import random

# %%
def generar_matriz(N):
    matriz= []
    for i in range (N):
        fila = []
        for j in range(N):
            fila.append(random.randint(1, 9))
        matriz.append(fila)
    return matriz

N = 5

matriz_aleatoria = generar_matriz(N)
for fila in matriz_aleatoria:
    print(fila)

def imprimir_matriz(matriz):
    for fila in matriz:
        fila_formateada = ' '.join(f'{elemento:2}' for elemento in fila)
        print(fila_formateada)
# Out:
# [8, 9, 8, 6, 1]
# [4, 1, 7, 7, 8]
# [5, 4, 8, 5, 9]
# [8, 7, 2, 5, 4]
# [1, 4, 1, 6, 4]

# %%
print("Matriz de 5x5")
m_5 = generar_matriz(5)
imprimir_matriz(m_5)
print("============")
print("Matriz de 10x10")
m_10 = generar_matriz(10)
imprimir_matriz(m_10)
print("============")
print("Matriz de 20x20")
m_20 = generar_matriz(20)
imprimir_matriz(m_20)
# Out:
# Matriz de 5x5
#  3  7  2  5  8
#  1  4  2  4  4
#  4  7  5  8  8
#  3  2  9  1  2
#  1  8  4  7  1
# ============
# Matriz de 10x10
#  4  6  1  5  6  8  2  6  7  5
#  1  3  9  2  7  9  4  3  7  1
#  4  2  7  2  9  7  1  5  5  8
#  7  6  7  8  7  8  9  9  9  8
#  2  7  1  9  1  3  6  3  6  7
#  4  9  9  8  1  5  2  5  7  8
#  1  5  2  6  2  2  4  4  6  9
#  9  9  6  5  6  9  5  8  6  9
#  3  1  7  3  3  1  7  5  2  9
#  3  6  6  8  7  1  5  3  4  9
# ============
# Matriz de 20x20
#  1  6  4  7  7  1  8  4  2  9  9  2  6  1  9  3  1  5  6  5
#  9  4  4  1  4  8  8  4  2  9  2  2  5  8  2  6  7  8  7  9
#  8  3  5  9  7  5  1  9  1  3  2  1  4  5  1  5  9  1  6  2
#  3  4  5  2  2  7  6  7  4  6  1  3  2  7  5  3  1  9  6  8
#  3  3  4  5  8  3  3  8  2  9  3  3  6  3  9  1  5  3  4  8
#  4  5  4  5  4  7  8  3  2  9  4  9  7  3  9  8  7  6  4  9
#  1  6  7  9  9  2  2  5  6  4  8  1  4  9  4  1  5  4  9  1
#  2  8  4  4  7  6  6  9  3  3  6  1  3  3  6  8  2  4  5  8
#  8  1  3  5  5  8  7  7  7  7  6  6  2  1  8  6  1  2  2  5
#  4  8  8  3  2  9  6  7  3  5  4  8  2  9  3  1  8  7  8  1
#  3  7  7  3  1  3  2  5  5  5  4  1  4  5  5  5  2  7  1  4
#  6  4  5  1  2  3  4  2  3  3  3  2  2  7  6  1  8  6  3  6
#  1  9  7  1  6  7  1  8  8  8  3  8  6  1  7  8  8  8  5  5
#  1  8  2  2  1  1  4  7  2  9  1  8  5  8  9  8  5  5  9  2
#  1  3  1  4  1  3  6  3  3  8  6  1  1  5  4  7  6  3  6  5
#  2  5  6  8  9  1  9  1  5  5  9  6  6  4  2  4  7  6  1  2
#  4  2  7  7  2  7  2  5  8  2  4  6  9  5  1  6  4  2  4  6
#  9  8  1  5  2  3  8  9  8  9  6  4  5  6  8  6  2  2  6  8
#  4  5  1  3  9  8  5  7  4  9  6  8  2  4  3  1  2  6  2  9
#  8  6  2  3  5  3  7  7  8  9  6  5  1  7  9  1  8  4  5  5
